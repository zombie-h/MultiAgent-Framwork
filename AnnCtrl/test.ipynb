# %%
import json

# %%
text =''' 
```json
[
    "Livestream Title: 'The Evolution of Trust'",
    "Hello everyone, and welcome!",
    "I'm excited to have you join.",
    "We’ll delve into trust today.",
    "Trust has evolved throughout history.",
    "Human interactions relied on trust.",
    "Trust once came from face-to-face.",
    "Shared experiences built this trust.",
    "Centralized institutions emerged later.",
    "These provided a sense of security.",
    "But this came with many costs.",
    "Fees, time, and privacy erosion.",
    "Tech has always aimed to enhance trust.",
    "The internet shifted our interactions.",
    "It also raised new trust issues.",
    "This sets the stage for blockchain.",
    "Blockchain challenges traditional norms.",
    "It redefines digital communication.",
    "Now to the birth of blockchain.",
    "It started from the Bitcoin vision.",
    "Blockchain is a decentralized system.",
    "It maintains a transparent ledger.",
    "Engage without trusting third parties.",
    "This 'trustless' system empowers individuals.",
    "Blockchain makes trust part of technology.",
    "Now, let's discuss decentralized identity.",
    "You control your digital identity.",
    "Choose what to share and with whom.",
    "This reduces identity theft risk.",
    "Data isn't centralized anymore.",
    "You reclaim ownership over your identity.",
    "Next, smart contracts automate agreements.",
    "They ensure terms are enforced directly.",
    "Real estate transactions become simpler.",
    "No waiting for paperwork anymore.",
    "Complete processes in minutes.",
    "Industries use smart contracts now.",
    "They minimize disputes and streamline ops.",
    "Challenges come with this technology.",
    "Misconceptions about blockchain exist.",
    "It's not just about cryptocurrency.",
    "Some say it's not secure.",
    "Others view it as too complex.",
    "These concerns stem from misunderstanding.",
    "We must address these challenges.",
    "Security, scalability, and regulations matter.",
    "Collaboration is essential for success.",
    "Blockchain has broad applications.",
    "Healthcare needs secure patient records.",
    "Voting systems require trustworthy systems.",
    "Digital art needs provenance and authenticity.",
    "Cross-industry collaboration unlocks potential.",
    "Where are we heading next?",
    "Web 3.0 and decentralization are trends.",
    "Future trust may not rely on institutions.",
    "It will depend on resilient technology.",
    "Let's have an interactive Q&A!",
    "What are your thoughts on blockchain?",
    "How will it transform our interactions?",
    "The power of community is vital.",
    "Blockchain reshapes trust and relationships.",
    "Envision a future with inherent trust.",
    "Thank you for joining me today!",
    "Let's continue the conversation online.",
    "Stay curious and proactive.",
    "Explore blockchain's transformative possibilities.",
    "Until next time, keep dreaming.",
    "Embrace the evolving landscape of trust.",
    "Goodbye for now!"
]
``` 
'''

output = json.loads()

# %%
output
